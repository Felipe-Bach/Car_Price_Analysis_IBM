# %% [markdown]
# <a href="https://colab.research.google.com/github/Felipe-Bach/carpriceanalysis_ibm/blob/main/Car_Price_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Importing Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from matplotlib import pyplot
import seaborn as sns
from scipy import stats
# %matplotlib inline 
from google.colab import files

# %%
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data'

# %%
df = pd.read_csv(url, encoding='latin-1', header = None)

# %%
df.head()
# Out:
#    0    1            2    3    4     5   ...    20   21    22  23  24     25
# 0   3    ?  alfa-romero  gas  std   two  ...   9.0  111  5000  21  27  13495
# 1   3    ?  alfa-romero  gas  std   two  ...   9.0  111  5000  21  27  16500
# 2   1    ?  alfa-romero  gas  std   two  ...   9.0  154  5000  19  26  16500
# 3   2  164         audi  gas  std  four  ...  10.0  102  5500  24  30  13950
# 4   2  164         audi  gas  std  four  ...   8.0  115  5500  18  22  17450
#
# [5 rows x 26 columns]

# %%
headers = ['symboling', 'normalized-losses', 'maker', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length',
          'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm',
           'city-mpg', 'highway-mpg', 'price']

# %%
df.columns = headers

# %%
df.head()
# Out:
#    symboling normalized-losses        maker  ... city-mpg highway-mpg  price
# 0          3                 ?  alfa-romero  ...       21          27  13495
# 1          3                 ?  alfa-romero  ...       21          27  16500
# 2          1                 ?  alfa-romero  ...       19          26  16500
# 3          2               164         audi  ...       24          30  13950
# 4          2               164         audi  ...       18          22  17450
#
# [5 rows x 26 columns]

# %%
# df.to_csv('carsprice.csv') 
# files.download('carsprice.csv')

# %% [markdown]
# ##Analyzing the type of Data

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# maker                 object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df.describe(include='all')
# Out:
#          symboling normalized-losses   maker  ...    city-mpg highway-mpg price
# count   205.000000               205     205  ...  205.000000  205.000000   205
# unique         NaN                52      22  ...         NaN         NaN   187
# top            NaN                 ?  toyota  ...         NaN         NaN     ?
# freq           NaN                41      32  ...         NaN         NaN     4
# mean      0.834146               NaN     NaN  ...   25.219512   30.751220   NaN
# std       1.245307               NaN     NaN  ...    6.542142    6.886443   NaN
# min      -2.000000               NaN     NaN  ...   13.000000   16.000000   NaN
# 25%       0.000000               NaN     NaN  ...   19.000000   25.000000   NaN
# 50%       1.000000               NaN     NaN  ...   24.000000   30.000000   NaN
# 75%       2.000000               NaN     NaN  ...   30.000000   34.000000   NaN
# max       3.000000               NaN     NaN  ...   49.000000   54.000000   NaN
#
# [11 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   maker              205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
#  16  engine-size        205 non-null    int64
#  17  fuel-system        205 non-null    object
#  18  bore               205 non-null    object
#  19  stroke             205 non-null    object
#  20  compression-ratio  205 non-null    float64
#  21  horsepower         205 non-null    object
#  22  peak-rpm           205 non-null    object
#  23  city-mpg           205 non-null    int64
#  24  highway-mpg        205 non-null    int64
#  25  price              205 non-null    object
# dtypes: float64(5), int64(5), object(16)
# memory usage: 41.8+ KB

# %% [markdown]
# ##Pre-Processing

# %% [markdown]
# Changing price type to float

# %%
#df['price'] = df['price'].astype(float)

# %% [markdown]
# Error returned because of str in price column ('?')

# %% [markdown]
# Cleanning DataFrame from '?' value

# %%
df.replace("?", np.nan, inplace = True)
df.head(5)
# Out:
#    symboling normalized-losses        maker  ... city-mpg highway-mpg  price
# 0          3               NaN  alfa-romero  ...       21          27  13495
# 1          3               NaN  alfa-romero  ...       21          27  16500
# 2          1               NaN  alfa-romero  ...       19          26  16500
# 3          2               164         audi  ...       24          30  13950
# 4          2               164         audi  ...       18          22  17450
#
# [5 rows x 26 columns]

# %% [markdown]
# ##Data Wrangling

# %% [markdown]
# ###Counting missing values per column

# %%
missing_data = df.isnull()
missing_data.head(5)
# Out:
#    symboling  normalized-losses  maker  ...  city-mpg  highway-mpg  price
# 0      False               True  False  ...     False        False  False
# 1      False               True  False  ...     False        False  False
# 2      False               True  False  ...     False        False  False
# 3      False              False  False  ...     False        False  False
# 4      False              False  False  ...     False        False  False
#
# [5 rows x 26 columns]

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print(missing_data[column].value_counts())
    print("")
# Out:
# symboling
# False    205
# Name: symboling, dtype: int64
#
# normalized-losses
# False    164
# True      41
# Name: normalized-losses, dtype: int64
#
# maker
# False    205
# Name: maker, dtype: int64
#
# fuel-type
# False    205
# Name: fuel-type, dtype: int64
#
# aspiration
# False    205
# Name: aspiration, dtype: int64
#
# num-of-doors
# False    203
# True       2
# Name: num-of-doors, dtype: int64
#
# body-style
# False    205
# Name: body-style, dtype: int64
#
# drive-wheels
# False    205
# Name: drive-wheels, dtype: int64
#
# engine-location
# False    205
# Name: engine-location, dtype: int64
#
# wheel-base
# False    205
# Name: wheel-base, dtype: int64
#
# length
# False    205
# Name: length, dtype: int64
#
# width
# False    205
# Name: width, dtype: int64
#
# height
# False    205
# Name: height, dtype: int64
#
# curb-weight
# False    205
# Name: curb-weight, dtype: int64
#
# engine-type
# False    205
# Name: engine-type, dtype: int64
#
# num-of-cylinders
# False    205
# Name: num-of-cylinders, dtype: int64
#
# engine-size
# False    205
# Name: engine-size, dtype: int64
#
# fuel-system
# False    205
# Name: fuel-system, dtype: int64
#
# bore
# False    201
# True       4
# Name: bore, dtype: int64
#
# stroke
# False    201
# True       4
# Name: stroke, dtype: int64
#
# compression-ratio
# False    205
# Name: compression-ratio, dtype: int64
#
# horsepower
# False    203
# True       2
# Name: horsepower, dtype: int64
#
# peak-rpm
# False    203
# True       2
# Name: peak-rpm, dtype: int64
#
# city-mpg
# False    205
# Name: city-mpg, dtype: int64
#
# highway-mpg
# False    205
# Name: highway-mpg, dtype: int64
#
# price
# False    201
# True       4
# Name: price, dtype: int64

# %% [markdown]
# Based on the summary above, each column has 205 rows of data and seven of the columns containing missing data:
#
# <ol>
#     <li>"normalized-losses": 41 missing data</li>
#     <li>"num-of-doors": 2 missing data</li>
#     <li>"bore": 4 missing data</li>
#     <li>"stroke" : 4 missing data</li>
#     <li>"horsepower": 2 missing data</li>
#     <li>"peak-rpm": 2 missing data</li>
#     <li>"price": 4 missing data</li>
# </ol>

# %% [markdown]
# Replacing data:
#
# By Mean: 'normalized-losses', 'bore', 'stroke', 'horsepower', 'peak-rpm'.
#
# By Frequency: 'num-of-doors'
#
# Drop row: 'price'.

# %% [markdown]
# ### Mean column "Normalized Losses"

# %%
mean_normloss = df['normalized-losses'].astype(float).mean(axis=0)
print(f'Mean of normalized losses: {mean_normloss}')
# Out:
# Mean of normalized losses: 122.0

# %%
df["normalized-losses"].replace(np.nan, mean_normloss, inplace=True)

# %% [markdown]
# ###Mean column "Bore"

# %%
mean_bore = df['bore'].astype(float).mean(axis=0)
print(f'Mean of bore: {mean_bore}')
# Out:
# Mean of bore: 3.3297512437810957

# %%
df['bore'].replace(np.nan, mean_bore, inplace=True)

# %% [markdown]
# ###Mean column 'Stroke'

# %%
mean_stroke = df['stroke'].astype(float).mean(axis=0)
print(f'Mean of column Stroke: {mean_stroke}')
# Out:
# Mean of column Stroke: 3.2554228855721337

# %%
df['stroke'].replace(np.nan, mean_stroke, inplace = True)

# %% [markdown]
# ###Mean column 'Horsepower'

# %%
mean_hp = df['horsepower'].astype(float).mean(axis=0)
print(f'mean of column HorsePower: {mean_hp}')
# Out:
# mean of column HorsePower: 104.25615763546799

# %%
df['horsepower'].replace(np.nan, mean_hp, inplace=True)

# %% [markdown]
# ###Mean column "Peak-RPM"

# %%
mean_peak_rpm = df['peak-rpm'].astype(float).mean(axis=0)
print(f'Mean of Peak-RPM: {mean_peak_rpm}')
# Out:
# Mean of Peak-RPM: 5125.369458128079

# %%
df['peak-rpm'].replace(np.nan, mean_peak_rpm, inplace=True)

# %% [markdown]
# ###Num of Doors

# %% [markdown]
# Checking most commom type of data on column 'num-of-doors'

# %%
df['num-of-doors'].value_counts().idxmax()
# Out:
# 'four'

# %%
df['num-of-doors'].replace(np.nan, 'four', inplace=True)

# %% [markdown]
# ###Dropping price column

# %%
df.dropna(subset=['price'], axis=0, inplace=True)

# %% [markdown]
# Reseting Index

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#    symboling normalized-losses        maker  ... city-mpg highway-mpg  price
# 0          3             122.0  alfa-romero  ...       21          27  13495
# 1          3             122.0  alfa-romero  ...       21          27  16500
# 2          1             122.0  alfa-romero  ...       19          26  16500
# 3          2               164         audi  ...       24          30  13950
# 4          2               164         audi  ...       18          22  17450
#
# [5 rows x 26 columns]

# %% [markdown]
# ###Converting Data to correct format

# %%
df[['bore', 'stroke', 'peak-rpm', 'price']] = df[['bore', 'stroke', 'peak-rpm', 'price']].astype(float)

# %%
df[['normalized-losses', 'horsepower']] = df[['normalized-losses', 'horsepower']].astype(int)

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# maker                 object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower             int64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %% [markdown]
# ###Data Standardization

# %%
df.head()
# Out:
#    symboling  normalized-losses        maker  ... city-mpg highway-mpg    price
# 0          3                122  alfa-romero  ...       21          27  13495.0
# 1          3                122  alfa-romero  ...       21          27  16500.0
# 2          1                122  alfa-romero  ...       19          26  16500.0
# 3          2                164         audi  ...       24          30  13950.0
# 4          2                164         audi  ...       18          22  17450.0
#
# [5 rows x 26 columns]

# %%
df['city-mpg'] = 235/df['city-mpg']
df.rename(columns={'city-mpg':'city-L/100km'}, inplace=True)

# %%
df['highway-mpg'] = 235/df['highway-mpg']

df.rename(columns={'highway-mpg': 'highway-L/100km'}, inplace=True)
          
df.head()
# Out:
#    symboling  normalized-losses  ... highway-L/100km    price
# 0          3                122  ...        8.703704  13495.0
# 1          3                122  ...        8.703704  16500.0
# 2          1                122  ...        9.038462  16500.0
# 3          2                164  ...        7.833333  13950.0
# 4          2                164  ...       10.681818  17450.0
#
# [5 rows x 26 columns]

# %% [markdown]
# ###Data Normalization

# %% [markdown]
# Process of data normalization: Simple Feature Scaling

# %%
df['length'] = df['length']/df['length'].max()
df['width'] = df['width']/df['width'].max()

# %%
df['height'] = df['height']/df['height'].max()

# %%
df[['length', 'width', 'height']].head()
# Out:
#      length     width    height
# 0  0.811148  0.890278  0.816054
# 1  0.811148  0.890278  0.816054
# 2  0.822681  0.909722  0.876254
# 3  0.848630  0.919444  0.908027
# 4  0.848630  0.922222  0.908027

# %% [markdown]
# ###Binning

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# maker                 object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower             int64
# peak-rpm             float64
# city-L/100km         float64
# highway-L/100km      float64
# price                float64
# dtype: object

# %%
# %matplotlib inline
plt.plt.hist(df["horsepower"])

plt.plt.xlabel("horsepower")
plt.plt.ylabel("count")
plt.plt.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
bins = np.linspace(min(df["horsepower"]), max(df["horsepower"]), 4)
bins_names = ['Low', 'Medium', 'High']

# %%
df['horsepower-binned'] = pd.cut(df['horsepower'], bins, labels=bins_names, include_lowest=True )
df[['horsepower','horsepower-binned']].head()
# Out:
#    horsepower horsepower-binned
# 0         111               Low
# 1         111               Low
# 2         154            Medium
# 3         102               Low
# 4         115               Low

# %%
df["horsepower-binned"].value_counts()
# Out:
# Low       153
# Medium     43
# High        5
# Name: horsepower-binned, dtype: int64

# %%
plt.bar(bins_names, df["horsepower-binned"].value_counts())

plt.plt.xlabel("horsepower")
plt.plt.ylabel("count")
plt.plt.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %% [markdown]
# OR

# %%
plt.plt.hist(df["horsepower"], bins = 3)


plt.plt.xlabel("horsepower")
plt.plt.ylabel("count")
plt.plt.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %% [markdown]
# ###Indicator Variable (Dummy Variable)

# %% [markdown]
# Fuel-Type: from str to int

# %% [markdown]
# dv = dummy variable

# %%
dv1 = pd.get_dummies(df["fuel-type"])
dv1.head()
# Out:
#    diesel  gas
# 0       0    1
# 1       0    1
# 2       0    1
# 3       0    1
# 4       0    1

# %%
dv1.rename(columns={'gas':'fuel-type-gas', 'diesel':'fuel-type-diesel'}, inplace=True)
dv1.head()
# Out:
#    fuel-type-diesel  fuel-type-gas
# 0                 0              1
# 1                 0              1
# 2                 0              1
# 3                 0              1
# 4                 0              1

# %%
df = pd.concat([df, dv1], axis=1)

# %%
df.drop("fuel-type", axis = 1, inplace=True)

# %% [markdown]
# Column "Aspiration": from str to int

# %%
dv2 = pd.get_dummies(df['aspiration'])
dv2.head()
# Out:
#    std  turbo
# 0    1      0
# 1    1      0
# 2    1      0
# 3    1      0
# 4    1      0

# %%
dv2.rename(columns={'std':'aspiration-type-std', 'turbo':'aspiration-type-turbo'}, inplace = True )

# %%
df = pd.concat([df, dv2],axis=1)

# %%
df.drop('aspiration', axis=1, inplace=True)

# %%
df.head()
# Out:
#    symboling  normalized-losses  ... aspiration-type-std aspiration-type-turbo
# 0          3                122  ...                   1                     0
# 1          3                122  ...                   1                     0
# 2          1                122  ...                   1                     0
# 3          2                164  ...                   1                     0
# 4          2                164  ...                   1                     0
#
# [5 rows x 29 columns]

# %% [markdown]
# ###Data has been cleaned

# %%
df.to_csv('clean_df.csv')

# %% [markdown]
# ##Finding Correlations

# %%
df.corr()
# Out:
#                        symboling  ...  aspiration-type-turbo
# symboling               1.000000  ...              -0.054615
# normalized-losses       0.466264  ...              -0.006911
# wheel-base             -0.535987  ...               0.256889
# length                 -0.365404  ...               0.230085
# width                  -0.242423  ...               0.305732
# height                 -0.550160  ...               0.090336
# curb-weight            -0.233118  ...               0.321955
# engine-size            -0.110581  ...               0.110040
# bore                   -0.140019  ...               0.227816
# stroke                 -0.008153  ...               0.218233
# compression-ratio      -0.182196  ...               0.307522
# horsepower              0.075810  ...               0.251159
# peak-rpm                0.279740  ...              -0.190057
# city-L/100km            0.066171  ...               0.157578
# highway-L/100km        -0.029807  ...               0.210720
# price                  -0.082391  ...               0.179578
# fuel-type-diesel       -0.196735  ...               0.408228
# fuel-type-gas           0.196735  ...              -0.408228
# aspiration-type-std     0.054615  ...              -1.000000
# aspiration-type-turbo  -0.054615  ...               1.000000
#
# [20 rows x 20 columns]

# %%
df[["horsepower", "price"]].corr()
# Out:
#             horsepower     price
# horsepower    1.000000  0.809607
# price         0.809607  1.000000

# %%
sns.regplot(x='horsepower', y='price', data=df)

# %%
df[["engine-size", "price"]].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %%
sns.regplot(x='engine-size', y='price', data=df)
plt.ylim(0,)
# Out:
# (0.0, 53148.599892366125)

# %%
df[['highway-L/100km', 'price']].corr()
# Out:
#                  highway-L/100km     price
# highway-L/100km         1.000000  0.801118
# price                   0.801118  1.000000

# %%
sns.regplot(x='highway-L/100km', y='price', data=df)

# %%
sns.boxplot(x="body-style", y="price", data=df)

# %%
sns.boxplot(x="engine-location", y="price", data=df)

# %%
sns.boxplot(x="drive-wheels", y="price", data=df)

# %%
df.describe(include=['object'])
# Out:
#          maker num-of-doors body-style  ... engine-type num-of-cylinders fuel-system
# count      201          201        201  ...         201              201         201
# unique      22            2          5  ...           6                7           8
# top     toyota         four      sedan  ...         ohc             four        mpfi
# freq        32          115         94  ...         145              157          92
#
# [4 rows x 8 columns]

# %%
drive_wheels_counts = df['drive-wheels'].value_counts().to_frame()
drive_wheels_counts.rename(columns={'drive-wheels': 'value_counts'}, inplace=True)
drive_wheels_counts.index.name='drive-wheels'
drive_wheels_counts.head()
# Out:
#               value_counts
# drive-wheels
# fwd                    118
# rwd                     75
# 4wd                      8

# %%
engine_loc_counts = df['engine-location'].value_counts().to_frame()
engine_loc_counts.rename(columns={'engine-location': 'value_counts'}, inplace=True)
engine_loc_counts.index.name = 'engine-location'
engine_loc_counts.head()
# Out:
#                  value_counts
# engine-location
# front                     198
# rear                        3

# %% [markdown]
# ###Pearson Correlation

# %% [markdown]
# Wheel-Base vs Price

# %%
pearson_coef, p_value = stats.pearsonr(df['wheel-base'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.584641822265508  with a P-value of P = 8.076488270733218e-20

# %% [markdown]
# Horsepower vs Price

# %%
pearson_coef, p_value = stats.pearsonr(df['horsepower'], df['price'])
print(f'Pearson Correlation {pearson_coef} and P-Value {p_value}')
# Out:
# Pearson Correlation 0.8096068016571054 and P-Value 6.273536270650504e-48

# %% [markdown]
# Length vs Price

# %%
pearson_coef, p_value = stats.pearsonr(df['length'], df['price'])
print(f'PC = {pearson_coef} and p-value = {p_value}')
# Out:
# PC = 0.6906283804483639 and p-value = 8.016477466159328e-30

# %% [markdown]
# Width vs Price

# %%
pearson_coef, p_value = stats.pearsonr(df['width'], df['price'])
print(f'PC = {pearson_coef} and P-value = {p_value}')
# Out:
# PC = 0.7512653440522673 and P-value = 9.200335510481646e-38

# %% [markdown]
# Curb-Weight vs Price

# %%
pearson_coef, p_value = stats.pearsonr(df['curb-weight'], df['price'])
print(f'PC = {pearson_coef} and p-value {p_value}')
# Out:
# PC = 0.8344145257702843 and p-value 2.189577238894065e-53

# %% [markdown]
# Engine-size vs Price

# %%
pearson_coef, p_value = stats.pearsonr(df['engine-size'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.8723351674455185  with a P-value of P = 9.265491622198389e-64

# %% [markdown]
# Bore vs Price

# %%
pearson_coef, p_value = stats.pearsonr(df['bore'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =  ", p_value )
# Out:
# The Pearson Correlation Coefficient is 0.5431553832626602  with a P-value of P =   8.049189483935489e-17

# %% [markdown]
# City-L/100km	 vs Price

# %%
pearson_coef, p_value = stats.pearsonr(df['city-L/100km'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.7898975136626943  with a P-value of P =  3.903106400939802e-44

# %% [markdown]
# Highway-L/100km vs Price

# %%
pc, p_value = stats.pearsonr(df['highway-L/100km'], df['price'])
print(f'pc = {pc} and p-value {p_value}')
# Out:
# pc = 0.8011176263981974 and p-value 3.046784581041456e-46

# %% [markdown]
# ##ANOVA

# %% [markdown]
# ###Drive Wheels

# %%
gt=df[['drive-wheels', 'body-style', 'price']].groupby(['drive-wheels'])
gt.head(2)
# Out:
#     drive-wheels   body-style    price
# 0            rwd  convertible  13495.0
# 1            rwd  convertible  16500.0
# 3            fwd        sedan  13950.0
# 4            4wd        sedan  17450.0
# 5            fwd        sedan  15250.0
# 136          4wd    hatchback   7603.0

# %%
gt.get_group('4wd')['price']
# Out:
# 4      17450.0
# 136     7603.0
# 140     9233.0
# 141    11259.0
# 144     8013.0
# 145    11694.0
# 150     7898.0
# 151     8778.0
# Name: price, dtype: float64

# %% [markdown]
# All wheels ANOVA test

# %%
f_val, p_val = stats.f_oneway(gt.get_group('fwd')['price'], gt.get_group('rwd')['price'], gt.get_group('4wd')['price'])  
 
print( "ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 67.95406500780399 , P = 3.3945443577151245e-23

# %% [markdown]
# FWD and RWD

# %%
f_val, p_val = stats.f_oneway(gt.get_group('fwd')['price'], gt.get_group('rwd')['price'])
print(f'ANOVA test: F= {f_val}, P= {p_val} ')
# Out:
# ANOVA test: F= 130.5533160959111, P= 2.2355306355677845e-23

# %% [markdown]
# 4WD and RWD

# %%
f_val, p_val = stats.f_oneway(gt.get_group('4wd')['price'], gt.get_group('rwd')['price'])
print(f'ANOVA test: F= {f_val}, P= {p_val}')
# Out:
# ANOVA test: F= 8.580681368924756, P= 0.004411492211225333

# %% [markdown]
# 4WD and FWD

# %%
f_val, p_val = stats.f_oneway(gt.get_group('4wd')['price'], gt.get_group('fwd')['price'])
print(f'ANOVA test: F= {f_val}, P= {p_val}')
# Out:
# ANOVA test: F= 0.665465750252303, P= 0.41620116697845666
